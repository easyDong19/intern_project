# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
AAPL_data = pd.read_csv('data/AAPL.csv')
GSPC_data = pd.read_csv('data/GSPC.csv')
AAPL_data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  0.936384  1.004464  0.907924  0.999442   0.847207  535796800
# 1  2000-01-04  0.966518  0.987723  0.903460  0.915179   0.775779  512377600
# 2  2000-01-05  0.926339  0.987165  0.919643  0.928571   0.787131  778321600
# 3  2000-01-06  0.947545  0.955357  0.848214  0.848214   0.719014  767972800
# 4  2000-01-07  0.861607  0.901786  0.852679  0.888393   0.753073  460734400

# %%
AAPL_data['log_Return'] = np.log(AAPL_data['Adj Close']).diff(1)
GSPC_data['log_Return'] = np.log(GSPC_data['Adj Close']).diff(1)

GSPC_data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971
# 1  2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044
# 2  2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985
# 3  2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951
# 4  2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971
#
#      Adj Close      Volume  Daily_Return  log_Return
# 0  1455.219971   931800000           NaN         NaN
# 1  1399.420044  1009000000     -0.038345   -0.039099
# 2  1402.109985  1085500000      0.001922    0.001920
# 3  1403.449951  1092300000      0.000956    0.000955
# 4  1441.469971  1225200000      0.027090    0.026730

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.plot(AAPL_data['log_Return'], label='AAPL', color='red')

plt.yticks(np.arange(-0.8,1,0.2))
plt.xticks(np.arange(0,4000,500))

plt.xlim(0,3500)

plt.grid(True)

plt.legend()
plt.xlabel('Time(day)')
plt.ylabel('Daily returns')

plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x7fd913a17e50>,
#   <matplotlib.axis.YTick at 0x7fd913a172b0>,
#   <matplotlib.axis.YTick at 0x7fd913a16430>,
#   <matplotlib.axis.YTick at 0x7fd913a1c550>,
#   <matplotlib.axis.YTick at 0x7fd913a1cdc0>,
#   <matplotlib.axis.YTick at 0x7fd913a1eaf0>,
#   <matplotlib.axis.YTick at 0x7fd913a0ec40>,
#   <matplotlib.axis.YTick at 0x7fd913a278b0>,
#   <matplotlib.axis.YTick at 0x7fd913a2b370>],
#  [Text(0, -0.8, '−0.8'),
#   Text(0, -0.6000000000000001, '−0.6'),
#   Text(0, -0.40000000000000013, '−0.4'),
#   Text(0, -0.20000000000000018, '−0.2'),
#   Text(0, -2.220446049250313e-16, '0.0'),
#   Text(0, 0.19999999999999973, '0.2'),
#   Text(0, 0.3999999999999997, '0.4'),
#   Text(0, 0.5999999999999996, '0.6'),
#   Text(0, 0.7999999999999996, '0.8')])
# ([<matplotlib.axis.XTick at 0x7fd8f2ef4d30>,
#   <matplotlib.axis.XTick at 0x7fd8f2ef4cd0>,
#   <matplotlib.axis.XTick at 0x7fd901989520>,
#   <matplotlib.axis.XTick at 0x7fd913a2f8e0>,
#   <matplotlib.axis.XTick at 0x7fd913a27460>,
#   <matplotlib.axis.XTick at 0x7fd913a2ff10>,
#   <matplotlib.axis.XTick at 0x7fd913a339a0>,
#   <matplotlib.axis.XTick at 0x7fd913a37730>],
#  [Text(0, 0, '0'),
#   Text(500, 0, '500'),
#   Text(1000, 0, '1000'),
#   Text(1500, 0, '1500'),
#   Text(2000, 0, '2000'),
#   Text(2500, 0, '2500'),
#   Text(3000, 0, '3000'),
#   Text(3500, 0, '3500')])
# (0.0, 3500.0)
# Text(0.5, 0, 'Time(day)')
# Text(0, 0.5, 'Daily returns')

# %%
plt.figure(figsize=(8,6))
plt.plot(GSPC_data['log_Return'], label='S&P500', color='red')

plt.yticks(np.arange(-0.10,0.15,0.05))
plt.xticks(np.arange(0,4000,500))

plt.xlim(0,3500)
plt.ylim(-0.15,0.15)


plt.grid(True)

plt.legend()
plt.xlabel('Time(day)')
plt.ylabel('Daily returns')

plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x7fd8d31df940>,
#   <matplotlib.axis.YTick at 0x7fd8d31df2e0>,
#   <matplotlib.axis.YTick at 0x7fd8d31d65e0>,
#   <matplotlib.axis.YTick at 0x7fd8f30a8340>,
#   <matplotlib.axis.YTick at 0x7fd8f30a8df0>],
#  [Text(0, -0.1, '−0.10'),
#   Text(0, -0.05, '−0.05'),
#   Text(0, 0.0, '0.00'),
#   Text(0, 0.05000000000000002, '0.05'),
#   Text(0, 0.1, '0.10')])
# ([<matplotlib.axis.XTick at 0x7fd8d31d6c40>,
#   <matplotlib.axis.XTick at 0x7fd8d31d6c10>,
#   <matplotlib.axis.XTick at 0x7fd8d31d6700>,
#   <matplotlib.axis.XTick at 0x7fd8f30aebb0>,
#   <matplotlib.axis.XTick at 0x7fd8f30b56a0>,
#   <matplotlib.axis.XTick at 0x7fd8f30b5f10>,
#   <matplotlib.axis.XTick at 0x7fd8f30bcc40>,
#   <matplotlib.axis.XTick at 0x7fd8f30bc430>],
#  [Text(0, 0, '0'),
#   Text(500, 0, '500'),
#   Text(1000, 0, '1000'),
#   Text(1500, 0, '1500'),
#   Text(2000, 0, '2000'),
#   Text(2500, 0, '2500'),
#   Text(3000, 0, '3000'),
#   Text(3500, 0, '3500')])
# (0.0, 3500.0)
# (-0.15, 0.15)
# Text(0.5, 0, 'Time(day)')
# Text(0, 0.5, 'Daily returns')

# %%
from scipy.stats import norm

plt.figure(figsize=(10,6))


plt.xticks(np.arange(-0.10,0.20,0.05))
plt.xlim(-0.10,0.15)
plt.ylim(0,50)

plt.hist(GSPC_data['log_Return'].dropna(), bins=50, density=True,edgecolor='black', linewidth=1.5)
mean = GSPC_data['log_Return'].mean()
std = GSPC_data['log_Return'].std()

x = np.arange(-1, 1,0.001)
plt.plot(x, norm.pdf(x, loc = mean, scale=std), linestyle="--", color="red")


plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x7fd913e487c0>,
#   <matplotlib.axis.XTick at 0x7fd913e48790>,
#   <matplotlib.axis.XTick at 0x7fd913e48220>,
#   <matplotlib.axis.XTick at 0x7fd913e75c10>,
#   <matplotlib.axis.XTick at 0x7fd913c65700>,
#   <matplotlib.axis.XTick at 0x7fd913c65f70>,
#   <matplotlib.axis.XTick at 0x7fd913e75430>],
#  [Text(-0.1, 0, '−0.10'),
#   Text(-0.05, 0, '−0.05'),
#   Text(0.0, 0, '0.00'),
#   Text(0.05000000000000002, 0, '0.05'),
#   Text(0.1, 0, '0.10'),
#   Text(0.15, 0, '0.15'),
#   Text(0.20000000000000004, 0, '0.20')])
# (-0.1, 0.15)
# (0.0, 50.0)
# (array([ 0.20992929,  0.        ,  0.        ,  0.06997643,  0.        ,
#          0.        ,  0.13995286,  0.13995286,  0.13995286,  0.13995286,
#          0.27990573,  0.34988216,  0.48983502,  0.41985859,  0.97967004,
#          1.74941079,  2.16926938,  4.40851519,  5.87802025, 10.77637046,
#         14.90497992, 23.9319396 , 39.04684881, 49.68326641, 37.36741446,
#         21.41278806, 12.10592266,  6.647761  ,  3.91868017,  1.81938722,
#          1.53948149,  1.25957577,  1.11962291,  0.48983502,  0.34988216,
#          0.13995286,  0.20992929,  0.        ,  0.20992929,  0.13995286,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.06997643,  0.06997643]),
#  array([-0.09469512, -0.09060978, -0.08652444, -0.0824391 , -0.07835376,
#         -0.07426842, -0.07018307, -0.06609773, -0.06201239, -0.05792705,
#         -0.05384171, -0.04975636, -0.04567102, -0.04158568, -0.03750034,
#         -0.033415  , -0.02932966, -0.02524431, -0.02115897, -0.01707363,
#         -0.01298829, -0.00890295, -0.0048176 , -0.00073226,  0.00335308,
#          0.00743842,  0.01152376,  0.01560911,  0.01969445,  0.02377979,
#          0.02786513,  0.03195047,  0.03603581,  0.04012116,  0.0442065 ,
#          0.04829184,  0.05237718,  0.05646252,  0.06054787,  0.06463321,
#          0.06871855,  0.07280389,  0.07688923,  0.08097457,  0.08505992,
#          0.08914526,  0.0932306 ,  0.09731594,  0.10140128,  0.10548663,
#          0.10957197]),
#  <BarContainer object of 50 artists>)

# %%
from scipy.stats import norm
plt.figure(figsize=(10,6))

plt.xticks(np.arange(-0.10,0.20,0.05))
plt.xlim(-0.10,0.15)
plt.ylim(0,30)

plt.hist(AAPL_data['log_Return'].dropna(), bins=50, density=True,edgecolor='black', linewidth=1.5)
mean = AAPL_data['log_Return'].mean()
std = AAPL_data['log_Return'].std()

x = np.arange(-1, 1,0.001)
plt.plot(x, norm.pdf(x, loc = mean, scale=std), linestyle="--", color="red")

plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x7fd8f334efd0>,
#   <matplotlib.axis.XTick at 0x7fd8f334efa0>,
#   <matplotlib.axis.XTick at 0x7fd8f334ea90>,
#   <matplotlib.axis.XTick at 0x7fd8f3382490>,
#   <matplotlib.axis.XTick at 0x7fd8f3382f40>,
#   <matplotlib.axis.XTick at 0x7fd8f3389a30>,
#   <matplotlib.axis.XTick at 0x7fd8f3375b80>],
#  [Text(-0.1, 0, '−0.10'),
#   Text(-0.05, 0, '−0.05'),
#   Text(0.0, 0, '0.00'),
#   Text(0.05000000000000002, 0, '0.05'),
#   Text(0.1, 0, '0.10'),
#   Text(0.15, 0, '0.15'),
#   Text(0.20000000000000004, 0, '0.20')])
# (-0.1, 0.15)
# (0.0, 30.0)
# (array([1.65929723e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.65929723e-02, 1.65929723e-02,
#         3.31859446e-02, 0.00000000e+00, 3.31859446e-02, 1.65929723e-02,
#         4.97789168e-02, 2.65487557e-01, 7.13497808e-01, 1.82522695e+00,
#         4.49669549e+00, 1.15818947e+01, 1.94469635e+01, 1.18307892e+01,
#         4.64603224e+00, 1.90819181e+00, 5.97347002e-01, 2.65487557e-01,
#         1.99115667e-01, 8.29648614e-02]),
#  array([-0.73124795, -0.71401911, -0.69679027, -0.67956143, -0.66233259,
#         -0.64510376, -0.62787492, -0.61064608, -0.59341724, -0.5761884 ,
#         -0.55895956, -0.54173072, -0.52450188, -0.50727305, -0.49004421,
#         -0.47281537, -0.45558653, -0.43835769, -0.42112885, -0.40390001,
#         -0.38667117, -0.36944234, -0.3522135 , -0.33498466, -0.31775582,
#         -0.30052698, -0.28329814, -0.2660693 , -0.24884046, -0.23161163,
#         -0.21438279, -0.19715395, -0.17992511, -0.16269627, -0.14546743,
#         -0.12823859, -0.11100975, -0.09378091, -0.07655208, -0.05932324,
#         -0.0420944 , -0.02486556, -0.00763672,  0.00959212,  0.02682096,
#          0.0440498 ,  0.06127863,  0.07850747,  0.09573631,  0.11296515,
#          0.13019399]),
#  <BarContainer object of 50 artists>)

# %%
from sklearn.preprocessing import MinMaxScaler

# 수정 종가 데이터를 0,1사이 값으로 조정
scaler = MinMaxScaler()

df_GSPC = GSPC_data[GSPC_data['Date']>='2011-12-05']
df_GSPC['scale_price'] = scaler.fit_transform(df_GSPC[['Adj Close']])
df_GSPC['log_scale_price'] = np.log(df_GSPC['scale_price']+1).diff(1)
df_GSPC
# Out:
# /var/folders/ws/lngrb3y14bx9ckr9196sk6qm0000gn/T/ipykernel_88266/2395461423.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GSPC['scale_price'] = scaler.fit_transform(df_GSPC[['Adj Close']])
# /var/folders/ws/lngrb3y14bx9ckr9196sk6qm0000gn/T/ipykernel_88266/2395461423.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GSPC['log_scale_price'] = np.log(df_GSPC['scale_price']+1).diff(1)
#             Date         Open         High          Low        Close  \
# 3000  2011-12-05  1244.329956  1266.729980  1244.329956  1257.079956
# 3001  2011-12-06  1257.189941  1266.030029  1253.030029  1258.469971
# 3002  2011-12-07  1258.140015  1267.060059  1244.800049  1261.010010
# 3003  2011-12-08  1260.869995  1260.869995  1231.469971  1234.349976
# 3004  2011-12-09  1234.479980  1258.250000  1234.479980  1255.189941
# ...          ...          ...          ...          ...          ...
# 3494  2013-11-21  1783.520020  1797.160034  1783.520020  1795.849976
# 3495  2013-11-22  1797.209961  1804.839966  1794.699951  1804.760010
# 3496  2013-11-25  1806.329956  1808.099976  1800.579956  1802.479980
# 3497  2013-11-26  1802.869995  1808.420044  1800.770020  1802.750000
# 3498  2013-11-27  1803.479980  1808.270020  1802.770020  1807.229980
#
#         Adj Close      Volume  Daily_Return  log_Return  scale_price  \
# 3000  1257.079956  4148060000      0.010287    0.010234     0.085947
# 3001  1258.469971  3734230000      0.001106    0.001105     0.088257
# 3002  1261.010010  4160540000      0.002018    0.002016     0.092477
# 3003  1234.349976  4298370000     -0.021142   -0.021368     0.048182
# 3004  1255.189941  3830610000      0.016883    0.016742     0.082807
# ...           ...         ...           ...         ...          ...
# 3494  1795.849976  3256630000      0.008129    0.008096     0.981093
# 3495  1804.760010  3055140000      0.004961    0.004949     0.995896
# 3496  1802.479980  2998540000     -0.001263   -0.001264     0.992108
# 3497  1802.750000  3427120000      0.000150    0.000150     0.992557
# 3498  1807.229980  2613590000      0.002485    0.002482     1.000000
#
#       log_scale_price
# 3000              NaN
# 3001         0.002124
# 3002         0.003870
# 3003        -0.041390
# 3004         0.032499
# ...               ...
# 3494         0.012218
# 3495         0.007445
# 3496        -0.001900
# 3497         0.000225
# 3498         0.003729
#
# [499 rows x 11 columns]
